# %% [markdown]
# # Update Customers
#
# Sometimes you need to update customers.

# %%
import logging
import requests
import json
import pandas as pd

# Start logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logging.debug('Start of program')
# Out:
# 2020-06-08 15:06:41,515 - DEBUG - Start of program

# %% [markdown]
# ## Import the Module
# Make sure your environment paths are set correctly if you are getting module not found errors.

# %%
from pyLightspeed.lsretail import old_api as lsretail
from pyLightspeed.lsecom import api as lsecom

# %% [markdown]
# ## Get Keys
# This example uses a file you will have to create on your local machine to store keys. This is not best practice - you should probably store your keys in environment variables - but is simpler for people just trying to test and play. See the example files in example\data and adjust with your information.

# %%
KEY_FILE = "D:\Development\.keys\lightspeed_keys.json"

with open(KEY_FILE) as f:
    keys = json.load(f)

store_data = {
            'account_id': keys["account_id"],
            'save_path': 'D:\\Development\\.keys\\'
            }

credentials = {
            'client_id': keys["client_id"],
            'client_secret': keys["client_secret"],
            'api_key': keys["api_key"],
            'api_secret': keys["api_secret"]
            }

# %% [markdown]
# ## Create a Connection
# Call the connection class, which will return an active connection to Lightspeed.

# %%
# Creates the connection to lightspeed, and returns a connection object with useful properties
lsr = lsretail.Connection(store_data, credentials)
# Out:
# 2020-06-08 15:06:41,616 - DEBUG - Creating new Lightspeed Connection to account_id : 190211
# 2020-06-08 15:06:41,617 - INFO - REFRESH TOKEN: Trying to refresh token...
# 2020-06-08 15:06:41,628 - DEBUG - REFRESH TOKEN: Found codes.json with refresh_token : b4568649397c51e5570492da37da8d438797d1d7
# 2020-06-08 15:06:41,634 - DEBUG - Starting new HTTPS connection (1): cloud.lightspeedapp.com:443
# 2020-06-08 15:06:42,052 - DEBUG - https://cloud.lightspeedapp.com:443 "POST /oauth/access_token.php HTTP/1.1" 200 None
# 2020-06-08 15:06:42,055 - DEBUG - REFRESH TOKEN: Token refreshed, expires in 1373 seconds
# 2020-06-08 15:06:42,057 - DEBUG - REFRESH TOKENS: Headers are now : {'authorization': 'Bearer aee84dca9603193766846f1bca29dab68956510b'}

# %% [markdown]
# ## Update Customers to allow emails
#
# By default, customers (who probably gave you their emails) do not have the box checked to allow emails. This goes through and checks those boxes.
# Note, Lightspeed uses this backwards "noEmail" field, so noEmail true means they wont get email.
#
# Get a list of customers, then loop through them updating their permissions.

# %%
    customers = lsr.list("Customer", filter = '&load_relations=["Contact"]&Contact.noEmail=true')
    data = {'Contact':{'noEmail': 'false','noPhone':'false','noMail':'false'}}

    for customer in customers:
        lsr.update("Customer", customer["customerID"], data)
        logging.debug(f"Updated {customer['customerID']} {customer['firstName']} {customer['lastName']}")
# Out:
# 020-06-08 15:26:53,496 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:26:53,827 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6145.json HTTP/1.1" 200 356
# 2020-06-08 15:26:53,869 - DEBUG - Updated 6145
# 2020-06-08 15:26:53,870 - DEBUG - MANAGE RATE: Used 57.358811855316 of 60.0 , refreshing at 1.0 and -161.0164361000061 sec. left on token.
# 2020-06-08 15:26:53,871 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:03,874 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:04,100 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6146.json HTTP/1.1" 200 379
# 2020-06-08 15:27:04,192 - DEBUG - Updated 6146
# 2020-06-08 15:27:04,193 - DEBUG - MANAGE RATE: Used 57.065621852875 of 60.0 , refreshing at 1.0 and -150.69404006004333 sec. left on token.
# 2020-06-08 15:27:04,194 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:14,196 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:14,436 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6148.json HTTP/1.1" 200 356
# 2020-06-08 15:27:14,467 - DEBUG - Updated 6148
# 2020-06-08 15:27:14,468 - DEBUG - MANAGE RATE: Used 56.745845079422 of 60.0 , refreshing at 1.0 and -140.41849184036255 sec. left on token.
# 2020-06-08 15:27:14,469 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:24,471 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:24,806 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6149.json HTTP/1.1" 200 356
# 2020-06-08 15:27:24,837 - DEBUG - Updated 6149
# 2020-06-08 15:27:24,838 - DEBUG - MANAGE RATE: Used 56.361749887466 of 60.0 , refreshing at 1.0 and -130.0482165813446 sec. left on token.
# 2020-06-08 15:27:24,839 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:34,840 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:35,198 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6150.json HTTP/1.1" 200 447
# 2020-06-08 15:27:35,234 - DEBUG - Updated 6150
# 2020-06-08 15:27:35,234 - DEBUG - MANAGE RATE: Used 55.989110946655 of 60.0 , refreshing at 1.0 and -119.652188539505 sec. left on token.
# 2020-06-08 15:27:35,235 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:45,238 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:45,580 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6151.json HTTP/1.1" 200 444
# 2020-06-08 15:27:45,617 - DEBUG - Updated 6151
# 2020-06-08 15:27:45,617 - DEBUG - MANAGE RATE: Used 55.585448980331 of 60.0 , refreshing at 1.0 and -109.26994156837463 sec. left on token.
# 2020-06-08 15:27:45,618 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:27:55,619 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:27:55,879 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6152.json HTTP/1.1" 200 378
# 2020-06-08 15:27:55,917 - DEBUG - Updated 6152
# 2020-06-08 15:27:55,918 - DEBUG - MANAGE RATE: Used 55.307067871094 of 60.0 , refreshing at 1.0 and -98.96851444244385 sec. left on token.
# 2020-06-08 15:27:55,919 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:05,920 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:06,248 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6153.json HTTP/1.1" 200 356
# 2020-06-08 15:28:06,303 - DEBUG - Updated 6153
# 2020-06-08 15:28:06,304 - DEBUG - MANAGE RATE: Used 54.935215950012 of 60.0 , refreshing at 1.0 and -88.58227753639221 sec. left on token.
# 2020-06-08 15:28:06,304 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:16,307 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:16,711 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6154.json HTTP/1.1" 200 447
# 2020-06-08 15:28:16,751 - DEBUG - Updated 6154
# 2020-06-08 15:28:16,752 - DEBUG - MANAGE RATE: Used 54.522937059402 of 60.0 , refreshing at 1.0 and -78.13420534133911 sec. left on token.
# 2020-06-08 15:28:16,753 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:26,755 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:27,062 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6155.json HTTP/1.1" 200 354
# 2020-06-08 15:28:27,112 - DEBUG - Updated 6155
# 2020-06-08 15:28:27,113 - DEBUG - MANAGE RATE: Used 54.133554935455 of 60.0 , refreshing at 1.0 and -67.77387356758118 sec. left on token.
# 2020-06-08 15:28:27,113 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:37,115 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:37,464 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6156.json HTTP/1.1" 200 355
# 2020-06-08 15:28:37,502 - DEBUG - Updated 6156
# 2020-06-08 15:28:37,503 - DEBUG - MANAGE RATE: Used 53.733142852783 of 60.0 , refreshing at 1.0 and -57.38367319107056 sec. left on token.
# 2020-06-08 15:28:37,504 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:47,507 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:47,766 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6157.json HTTP/1.1" 200 458
# 2020-06-08 15:28:47,808 - DEBUG - Updated 6157
# 2020-06-08 15:28:47,809 - DEBUG - MANAGE RATE: Used 53.432405948639 of 60.0 , refreshing at 1.0 and -47.07717728614807 sec. left on token.
# 2020-06-08 15:28:47,810 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:28:57,812 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:28:58,058 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6158.json HTTP/1.1" 200 357
# 2020-06-08 15:28:58,109 - DEBUG - Updated 6158
# 2020-06-08 15:28:58,110 - DEBUG - MANAGE RATE: Used 53.114130020142 of 60.0 , refreshing at 1.0 and -36.77675676345825 sec. left on token.
# 2020-06-08 15:28:58,110 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:29:08,112 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:08,459 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6159.json HTTP/1.1" 200 355
# 2020-06-08 15:29:08,550 - DEBUG - Updated 6159
# 2020-06-08 15:29:08,551 - DEBUG - MANAGE RATE: Used 52.713387966156 of 60.0 , refreshing at 1.0 and -26.336070775985718 sec. left on token.
# 2020-06-08 15:29:08,551 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:29:18,554 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:19,191 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6160.json HTTP/1.1" 200 389
# 2020-06-08 15:29:19,238 - DEBUG - Updated 6160
# 2020-06-08 15:29:19,239 - DEBUG - MANAGE RATE: Used 52.02064204216 of 60.0 , refreshing at 1.0 and -15.647639751434326 sec. left on token.
# 2020-06-08 15:29:19,239 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:29:29,242 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:29,640 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6161.json HTTP/1.1" 200 355
# 2020-06-08 15:29:29,685 - DEBUG - Updated 6161
# 2020-06-08 15:29:29,686 - DEBUG - MANAGE RATE: Used 51.54657793045 of 60.0 , refreshing at 1.0 and -5.200570106506348 sec. left on token.
# 2020-06-08 15:29:29,686 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:29:39,688 - DEBUG - MANAGE RATE: Token needs a refresh
# 2020-06-08 15:29:44,689 - INFO - REFRESH TOKEN: Trying to refresh token...
# 2020-06-08 15:29:44,696 - DEBUG - REFRESH TOKEN: Found codes.json with refresh_token : b4568649397c51e5570492da37da8d438797d1d7
# 2020-06-08 15:29:44,700 - DEBUG - Starting new HTTPS connection (1): cloud.lightspeedapp.com:443
# 2020-06-08 15:29:45,096 - DEBUG - https://cloud.lightspeedapp.com:443 "POST /oauth/access_token.php HTTP/1.1" 200 None
# 2020-06-08 15:29:45,098 - DEBUG - REFRESH TOKEN: Token refreshed, expires in 1800 seconds
# 2020-06-08 15:29:45,099 - DEBUG - REFRESH TOKENS: Headers are now : {'authorization': 'Bearer 1a6f9ae8fccb3a49d5d277a6ff76ff78f15004e1'}
# 2020-06-08 15:29:45,103 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:45,431 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6162.json HTTP/1.1" 200 446
# 2020-06-08 15:29:45,481 - DEBUG - Updated 6162
# 2020-06-08 15:29:45,482 - DEBUG - MANAGE RATE: Used 45.759773015976 of 60.0 , refreshing at 1.0 and -1799.6159999370575 sec. left on token.
# 2020-06-08 15:29:45,485 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:45,722 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6163.json HTTP/1.1" 200 379
# 2020-06-08 15:29:45,769 - DEBUG - Updated 6163
# 2020-06-08 15:29:45,770 - DEBUG - MANAGE RATE: Used 55.461039066315 of 60.0 , refreshing at 1.0 and -1799.3277969360352 sec. left on token.
# 2020-06-08 15:29:45,771 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:29:55,772 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:29:56,045 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6164.json HTTP/1.1" 200 377
# 2020-06-08 15:29:56,086 - DEBUG - Updated 6164
# 2020-06-08 15:29:56,087 - DEBUG - MANAGE RATE: Used 55.129612922668 of 60.0 , refreshing at 1.0 and -1789.0103495121002 sec. left on token.
# 2020-06-08 15:29:56,088 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:06,090 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:06,431 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6165.json HTTP/1.1" 200 458
# 2020-06-08 15:30:06,487 - DEBUG - Updated 6165
# 2020-06-08 15:30:06,488 - DEBUG - MANAGE RATE: Used 54.762899875641 of 60.0 , refreshing at 1.0 and -1778.610145330429 sec. left on token.
# 2020-06-08 15:30:06,489 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:16,490 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:16,830 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6166.json HTTP/1.1" 200 451
# 2020-06-08 15:30:16,880 - DEBUG - Updated 6166
# 2020-06-08 15:30:16,881 - DEBUG - MANAGE RATE: Used 54.379870891571 of 60.0 , refreshing at 1.0 and -1768.2169206142426 sec. left on token.
# 2020-06-08 15:30:16,882 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:26,885 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:27,439 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6167.json HTTP/1.1" 200 351
# 2020-06-08 15:30:27,494 - DEBUG - Updated 6167
# 2020-06-08 15:30:27,495 - DEBUG - MANAGE RATE: Used 53.792531967163 of 60.0 , refreshing at 1.0 and -1757.6031093597412 sec. left on token.
# 2020-06-08 15:30:27,495 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:37,497 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:37,714 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6168.json HTTP/1.1" 200 351
# 2020-06-08 15:30:37,782 - DEBUG - Updated 6168
# 2020-06-08 15:30:37,783 - DEBUG - MANAGE RATE: Used 53.481406927109 of 60.0 , refreshing at 1.0 and -1747.3150300979614 sec. left on token.
# 2020-06-08 15:30:37,784 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:47,787 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:48,159 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6169.json HTTP/1.1" 200 445
# 2020-06-08 15:30:48,260 - DEBUG - Updated 6169
# 2020-06-08 15:30:48,261 - DEBUG - MANAGE RATE: Used 53.062799930573 of 60.0 , refreshing at 1.0 and -1736.8364114761353 sec. left on token.
# 2020-06-08 15:30:48,262 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:30:58,264 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:30:58,519 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6170.json HTTP/1.1" 200 352
# 2020-06-08 15:30:58,581 - DEBUG - Updated 6170
# 2020-06-08 15:30:58,582 - DEBUG - MANAGE RATE: Used 52.685980081558 of 60.0 , refreshing at 1.0 and -1726.5159583091736 sec. left on token.
# 2020-06-08 15:30:58,583 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:31:08,584 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:31:09,000 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6171.json HTTP/1.1" 200 374
# 2020-06-08 15:31:09,054 - DEBUG - Updated 6171
# 2020-06-08 15:31:09,055 - DEBUG - MANAGE RATE: Used 52.235122919083 of 60.0 , refreshing at 1.0 and -1716.0429921150208 sec. left on token.
# 2020-06-08 15:31:09,056 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:31:19,058 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:31:19,293 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6172.json HTTP/1.1" 200 353
# 2020-06-08 15:31:19,343 - DEBUG - Updated 6172
# 2020-06-08 15:31:19,344 - DEBUG - MANAGE RATE: Used 51.890334844589 of 60.0 , refreshing at 1.0 and -1705.7534883022308 sec. left on token.
# 2020-06-08 15:31:19,345 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:31:29,350 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:31:29,699 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6173.json HTTP/1.1" 200 353
# 2020-06-08 15:31:29,738 - DEBUG - Updated 6173
# 2020-06-08 15:31:29,739 - DEBUG - MANAGE RATE: Used 51.515299081802 of 60.0 , refreshing at 1.0 and -1695.3587017059326 sec. left on token.
# 2020-06-08 15:31:29,739 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:31:39,743 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:31:39,999 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6174.json HTTP/1.1" 200 354
# 2020-06-08 15:31:40,099 - DEBUG - Updated 6174
# 2020-06-08 15:31:40,100 - DEBUG - MANAGE RATE: Used 51.194627046585 of 60.0 , refreshing at 1.0 and -1684.997487783432 sec. left on token.
# 2020-06-08 15:31:40,101 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:31:50,103 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:31:50,461 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6175.json HTTP/1.1" 200 374
# 2020-06-08 15:31:50,506 - DEBUG - Updated 6175
# 2020-06-08 15:31:50,506 - DEBUG - MANAGE RATE: Used 50.726665973663 of 60.0 , refreshing at 1.0 and -1674.592300415039 sec. left on token.
# 2020-06-08 15:31:50,507 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:00,508 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:00,986 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6176.json HTTP/1.1" 200 354
# 2020-06-08 15:32:01,027 - DEBUG - Updated 6176
# 2020-06-08 15:32:01,027 - DEBUG - MANAGE RATE: Used 50.203299045563 of 60.0 , refreshing at 1.0 and -1664.070428609848 sec. left on token.
# 2020-06-08 15:32:01,028 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:11,030 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:11,326 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6177.json HTTP/1.1" 200 356
# 2020-06-08 15:32:11,396 - DEBUG - Updated 6177
# 2020-06-08 15:32:11,397 - DEBUG - MANAGE RATE: Used 49.863368034363 of 60.0 , refreshing at 1.0 and -1653.7011470794678 sec. left on token.
# 2020-06-08 15:32:11,399 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:11,618 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6178.json HTTP/1.1" 200 353
# 2020-06-08 15:32:11,660 - DEBUG - Updated 6178
# 2020-06-08 15:32:11,661 - DEBUG - MANAGE RATE: Used 59.564403057098 of 60.0 , refreshing at 1.0 and -1653.4368522167206 sec. left on token.
# 2020-06-08 15:32:11,662 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:21,664 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:22,026 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6179.json HTTP/1.1" 200 437
# 2020-06-08 15:32:22,066 - DEBUG - Updated 6179
# 2020-06-08 15:32:22,067 - DEBUG - MANAGE RATE: Used 59.154700040817 of 60.0 , refreshing at 1.0 and -1643.0306692123413 sec. left on token.
# 2020-06-08 15:32:22,068 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:32,069 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:32,339 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6180.json HTTP/1.1" 200 354
# 2020-06-08 15:32:32,403 - DEBUG - Updated 6180
# 2020-06-08 15:32:32,404 - DEBUG - MANAGE RATE: Used 58.86572599411 of 60.0 , refreshing at 1.0 and -1632.695296049118 sec. left on token.
# 2020-06-08 15:32:32,404 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:42,406 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:42,941 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6181.json HTTP/1.1" 200 375
# 2020-06-08 15:32:42,978 - DEBUG - Updated 6181
# 2020-06-08 15:32:42,979 - DEBUG - MANAGE RATE: Used 58.255123853683 of 60.0 , refreshing at 1.0 and -1622.118352174759 sec. left on token.
# 2020-06-08 15:32:42,980 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:32:52,983 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:32:53,236 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6182.json HTTP/1.1" 200 376
# 2020-06-08 15:32:53,276 - DEBUG - Updated 6182
# 2020-06-08 15:32:53,277 - DEBUG - MANAGE RATE: Used 57.932353973389 of 60.0 , refreshing at 1.0 and -1611.8208742141724 sec. left on token.
# 2020-06-08 15:32:53,278 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:33:03,279 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:33:03,656 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6183.json HTTP/1.1" 200 376
# 2020-06-08 15:33:03,897 - DEBUG - Updated 6183
# 2020-06-08 15:33:03,898 - DEBUG - MANAGE RATE: Used 57.527343988419 of 60.0 , refreshing at 1.0 and -1601.200263261795 sec. left on token.
# 2020-06-08 15:33:03,898 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:33:13,900 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# 2020-06-08 15:33:14,158 - DEBUG - https://api.lightspeedapp.com:443 "PUT /API/Account/190211/Customer/6184.json HTTP/1.1" 200 378
# 2020-06-08 15:33:14,264 - DEBUG - Updated 6184
# 2020-06-08 15:33:14,264 - DEBUG - MANAGE RATE: Used 57.045852899551 of 60.0 , refreshing at 1.0 and -1590.8339755535126 sec. left on token.
# 2020-06-08 15:33:14,265 - INFO - MANAGE RATE: Bucket is almost full, taking a break.
# 2020-06-08 15:33:24,267 - DEBUG - Starting new HTTPS connection (1): api.lightspeedapp.com:443
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Development\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# D:\Development\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# D:\Development\Anaconda\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Development\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# D:\Development\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# D:\Development\Anaconda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# D:\Development\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# D:\Development\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000001B6EB67D1C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Development\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# D:\Development\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# D:\Development\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='api.lightspeedapp.com', port=443): Max retries exceeded with url: /API/Account/190211/Customer/6185.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001B6EB67D1C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-259d0722ef95> in <module>
#       3
#       4 for customer in customers:
# ----> 5     lsr.update("Customer", customer["customerID"], data)
#       6     logging.debug(f'Updated {customer["customerID"]}')
#       7
#
# D:\Development\Repositories\pyLightspeed\lsretail\old_api.py in update(self, resource, id, payload)
#     225         try:
#     226             url = self.api_url + resource + "/"+ id + '.json'
# --> 227             self.response = requests.put(url, data=json.dumps(payload), headers=self.headers)
#     228             self.response.raise_for_status()
#     229
#
# D:\Development\Anaconda\lib\site-packages\requests\api.py in put(url, data, **kwargs)
#     129     """
#     130
# --> 131     return request('put', url, data=data, **kwargs)
#     132
#     133
#
# D:\Development\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\Development\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\Development\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\Development\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.lightspeedapp.com', port=443): Max retries exceeded with url: /API/Account/190211/Customer/6185.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001B6EB67D1C8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %% [markdown]
# ## Update eCom Customers
# eCom customers need a record in subscriptions with a matching email address.

# %%
lse = lsecom.Connection(store_data, credentials)
# Out:
# 2020-04-20 17:37:55,473 - DEBUG - LS ECOM: Creating new Lightspeed Ecom to account_id : 190211

# %%
customers = lse.list("customers")
subscriptions = lse.list("subscriptions")
# Out:
# 2020-04-20 17:38:38,155 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 17:38:38,477 - DEBUG - https://api.shoplightspeed.com:443 "GET /en/customers/count.json HTTP/1.1" 200 None
# 2020-04-20 17:38:38,482 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 17:38:38,853 - DEBUG - https://api.shoplightspeed.com:443 "GET /en/customers.json?page=1&limit=250 HTTP/1.1" 200 None
# 2020-04-20 17:38:39,042 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 17:38:39,395 - DEBUG - https://api.shoplightspeed.com:443 "GET /en/subscriptions/count.json HTTP/1.1" 200 None
# 2020-04-20 17:38:39,401 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 17:38:39,738 - DEBUG - https://api.shoplightspeed.com:443 "GET /en/subscriptions.json?page=1&limit=250 HTTP/1.1" 200 None

# %%
for customer in customers:
    # We are looking for matches
    match = False
    # Look at each subscriber and see if they are the customer
    for subscriber in subscriptions:
        if subscriber['email'] == customer['email']:
            #if they are, we have a match
            match = True
    # If there isn't a match, we need to subscribe them
    if match == False:    
        logging.debug(f"Subscribing {customer['firstname']} {customer['lastname']} {customer['email']}")
        data = {
                "subscription": {
                    "isConfirmed": True,
                    "email": customer['email'],
                    "firstname": customer['firstname'],
                    "lastname": customer['lastname'],
                    "doNotifyConfirmed": False,
                    "language": "US"
                    }
                }
        lse.create("subscriptions", data)
# Out:
# 2020-04-20 18:01:51,743 - DEBUG - Subscribing Melissa Belmont mbelmont_2000@yahoo.com
# 2020-04-20 18:01:51,748 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:52,181 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:52,184 - DEBUG - Subscribing Trish Holloway tksholloway@comcast.net
# 2020-04-20 18:01:52,187 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:52,542 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:52,547 - DEBUG - Subscribing David Ross drnflight@sbcglobal.net
# 2020-04-20 18:01:52,552 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:52,915 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:52,919 - DEBUG - Subscribing Courtney O’Bannon courtneyo1979@gmail.com
# 2020-04-20 18:01:52,923 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:53,257 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:53,261 - DEBUG - Subscribing Gerri Kramer gerrifkramer@gmail.com
# 2020-04-20 18:01:53,264 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:53,612 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:53,617 - DEBUG - Subscribing Barbara Moritz WilbertWG18#@gmail.com
# 2020-04-20 18:01:53,620 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:53,983 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None
# 2020-04-20 18:01:53,993 - DEBUG - Subscribing Marjorie Wright Ncmarjwright@yahoo.com
# 2020-04-20 18:01:53,996 - DEBUG - Starting new HTTPS connection (1): api.shoplightspeed.com:443
# 2020-04-20 18:01:54,390 - DEBUG - https://api.shoplightspeed.com:443 "POST /en/subscriptions.json HTTP/1.1" 201 None

# %% [markdown]
# # Update Existing eCom Customers
#
# This updates customers who's name are messerd up

# %%
    lse = Connection(store_data, credentials)

    customers = lse.list("customers")
    subscriptions = lse.list("subscriptions")
    for customer in customers:
        match = False
        for subscriber in subscriptions:
            if lower(subscriber['email']) == lower(customer['email']):
                if subscriber['firstname'] != customer['firstname']: 
                    logging.debug(f"Updating name {customer['email']}")
                    data = {
                            "subscription": {
                                "isConfirmed": True,
                                "email": customer['email'],
                                "firstname": customer['firstname'],
                                "lastname": customer['lastname'],
                                "doNotifyConfirmed": False,
                                "language": "US"
                                }
                            }
                    
                    lse.update("subscriptions", subscriber["id"], data)
